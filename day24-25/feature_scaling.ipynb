# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #1) Standardization
#
# x' = (x-xbar)/standard-deviation

# %% [markdown]
# it helps with algorithm like knn where similarity in scale of columns is required!
#
#
# Also, After train_test_split only shall we do the feature scaling, where we fit only the train data, but we trainsform both the train and test of the X

# %% [markdown]
# #2) Normalization
#
# i) MinMaxScaler :- (x - xmin)/(xmax - xmin)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wine_data.csv" , header = None , usecols = [0,1,2] )
df.columns= ['Class label' , "Alcohol" , "Malic Acid"]
df
# Out:
#      Class label  Alcohol  Malic Acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic Acid'])
# Out:
# <Axes: xlabel='Malic Acid', ylabel='Density'>

# %%
colours = {1: 'blue' , 3: 'green' , 2: 'red'}
sns.scatterplot(x=df['Alcohol'] , y=df['Malic Acid'], hue = df['Class label'], palette = colours)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
x_train , x_test, y_train, y_test = train_test_split( df.iloc[:, 1:3] , df.iloc[:,0] , test_size=0.3 , random_state= 42 )
x_test
# Out:
#      Alcohol  Malic Acid
# 19     13.64        3.10
# 45     14.21        4.04
# 140    12.93        2.81
# 30     13.73        1.50
# 67     12.37        1.17
# 16     14.30        1.92
# 119    12.00        3.43
# 174    13.40        3.91
# 109    11.61        1.35
# 141    13.36        2.56
# 24     13.50        1.81
# 150    13.50        3.12
# 41     13.41        3.84
# 118    12.77        3.43
# 15     13.63        1.81
# 111    12.52        2.43
# 113    11.41        0.74
# 82     12.08        1.13
# 9      13.86        1.35
# 114    12.08        1.39
# 18     14.19        1.59
# 66     13.11        1.01
# 60     12.33        1.10
# 169    13.40        4.60
# 171    12.77        2.39
# 164    13.78        2.76
# 117    12.42        1.61
# 65     12.37        1.21
# 90     12.08        1.83
# 55     13.56        1.73
# 29     14.02        1.68
# 128    12.37        1.63
# 145    13.16        3.57
# 31     13.58        1.66
# 12     13.75        1.73
# 42     13.88        1.89
# ...

# %%
x_train
# Out:
#      Alcohol  Malic Acid
# 138    13.49        3.59
# 104    12.51        1.73
# 78     12.33        0.99
# 36     13.28        1.64
# 93     12.29        2.83
# ..       ...         ...
# 71     13.86        1.51
# 106    12.25        1.73
# 14     14.38        1.87
# 92     12.69        1.53
# 102    12.34        2.45
#
# [124 rows x 2 columns]

# %%
Skale = MinMaxScaler()
Skale.fit(x_train)
x_trains = Skale.transform (x_train)
x_tests = Skale.transform(x_test)
x_tests
# Out:
# array([[ 0.68684211,  0.45010183],
#        [ 0.83684211,  0.64154786],
#        [ 0.5       ,  0.3910387 ],
#        [ 0.71052632,  0.12423625],
#        [ 0.35263158,  0.05702648],
#        [ 0.86052632,  0.20977597],
#        [ 0.25526316,  0.51731161],
#        [ 0.62368421,  0.61507128],
#        [ 0.15263158,  0.09368635],
#        [ 0.61315789,  0.3401222 ],
#        [ 0.65      ,  0.18737271],
#        [ 0.65      ,  0.45417515],
#        [ 0.62631579,  0.60081466],
#        [ 0.45789474,  0.51731161],
#        [ 0.68421053,  0.18737271],
#        [ 0.39210526,  0.31364562],
#        [ 0.1       , -0.0305499 ],
#        [ 0.27631579,  0.04887984],
#        [ 0.74473684,  0.09368635],
#        [ 0.27631579,  0.10183299],
#        [ 0.83157895,  0.14256619],
#        [ 0.54736842,  0.02443992],
#        [ 0.34210526,  0.04276986],
#        [ 0.62368421,  0.75560081],
#        [ 0.45789474,  0.30549898],
#        [ 0.72368421,  0.3808554 ],
#        [ 0.36578947,  0.14663951],
# ...

# %%
x_trains = pd.DataFrame(x_trains, columns = x_train.columns)
x_tests = pd.DataFrame(x_tests , columns = x_train.columns)

# %%
np.round(x_train.describe() ,4)
# Out:
#         Alcohol  Malic Acid
# count  124.0000    124.0000
# mean    12.9633      2.4030
# std      0.8415      1.1023
# min     11.0300      0.8900
# 25%     12.2900      1.6400
# 50%     12.9450      1.9000
# 75%     13.6950      3.1700
# max     14.8300      5.8000

# %%
np.round(x_trains.describe() ,4)
# Out:
#         Alcohol  Malic Acid
# count  124.0000    124.0000
# mean     0.5088      0.3081
# std      0.2214      0.2245
# min      0.0000      0.0000
# 25%      0.3316      0.1527
# 50%      0.5039      0.2057
# 75%      0.7013      0.4644
# max      1.0000      1.0000

# %%
fig, (ax1,ax2) = plt.subplots(ncols =2 , figsize=(12,5))

ax1.scatter(x_trains['Alcohol'] , x_trains['Malic Acid'] , c = y_train)
ax1.set_title("Before Scaling")

ax2.scatter(x_trains['Alcohol'], x_trains['Malic Acid'] , c = y_train)
ax2.set_title("After Scaling")

plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(ncols =2 , figsize=(12,5))

sns.kdeplot(x_train['Alcohol'] , ax =ax1)
sns.kdeplot(x_train['Malic Acid'] ,ax =ax1)
ax1.set_title("Before Scaling")

sns.kdeplot(x_trains['Alcohol'], ax =ax2)
sns.kdeplot( x_trains['Malic Acid'] , ax =ax2)
ax2.set_title("After Scaling")

plt.show()

# %% [markdown]
# other types of Normalisation involve
# i) Mean Normalization :- useful where centered data is required , for that standardization is helpful too! and there is no library involved for it
#
# ii) Mean Absolute :- useful in case of sparse data and has a sklearn library named MaxAbsScaler

# %% [markdown]
# Robust Scaling :- usefull when there are a lot of outliers! and is having library RobustScaler!

# %% [markdown]
# ##Normalization vs Standardization!
#
# Figure out by some simple Questions
#
# 1)Is feature scaling Required?
#
# then realize:
# if u know min and Max : use MinMaxScaler
# if u dont know the data : use StandardScaler
# if u have many outliers : use RobustScaler
# if u have sparse data : use MaxAbsScaler
